# %%
import pandas as pd
import numpy as np
from numpy import mean
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from pmdarima.arima import auto_arima
import fbprophet as fb

# %%
top_technician_agg = pd.read_csv("top_technician_agg.csv")
top_technician_agg
# Out:
#         assigned_to sys_created_on  ticket_counts
# 0    Bender, Brendt     2018-01-14             27
# 1    Bender, Brendt     2018-01-21             63
# 2    Bender, Brendt     2018-01-28             61
# 3    Bender, Brendt     2018-02-04             75
# 4    Bender, Brendt     2018-02-11             66
# 5    Bender, Brendt     2018-02-18             59
# 6    Bender, Brendt     2018-02-25             77
# 7    Bender, Brendt     2018-03-04             72
# 8    Bender, Brendt     2018-03-11             72
# 9    Bender, Brendt     2018-03-18             81
# 10   Bender, Brendt     2018-03-25             58
# 11   Bender, Brendt     2018-04-01             52
# 12   Bender, Brendt     2018-04-08             55
# 13   Bender, Brendt     2018-04-15             49
# 14   Bender, Brendt     2018-04-22             47
# 15   Bender, Brendt     2018-04-29             57
# 16   Bender, Brendt     2018-05-06             66
# 17   Bender, Brendt     2018-05-13             61
# 18   Bender, Brendt     2018-05-20             70
# 19   Bender, Brendt     2018-05-27             88
# 20   Bender, Brendt     2018-06-03            108
# 21   Bender, Brendt     2018-06-10            114
# 22   Bender, Brendt     2018-06-17            140
# 23   Bender, Brendt     2018-06-24            122
# 24   Bender, Brendt     2018-07-01             66
# 25   Bender, Brendt     2018-07-08             51
# 26   Bender, Brendt     2018-07-15             53
# 27   Bender, Brendt     2018-07-22             55
# 28   Bender, Brendt     2018-07-29             53
# 29   Bender, Brendt     2018-08-05             55
# ..              ...            ...            ...
# 861  Zellmer, Jamie     2018-05-06             40
# 862  Zellmer, Jamie     2018-05-13             38
# 863  Zellmer, Jamie     2018-05-20            109
# 864  Zellmer, Jamie     2018-05-27            108
# 865  Zellmer, Jamie     2018-06-03             88
# 866  Zellmer, Jamie     2018-06-10             86
# 867  Zellmer, Jamie     2018-06-17             90
# 868  Zellmer, Jamie     2018-06-24             56
# 869  Zellmer, Jamie     2018-07-01             72
# 870  Zellmer, Jamie     2018-07-08             30
# 871  Zellmer, Jamie     2018-07-15             20
# 872  Zellmer, Jamie     2018-07-22             16
# 873  Zellmer, Jamie     2018-07-29             16
# 874  Zellmer, Jamie     2018-08-05             11
# 875  Zellmer, Jamie     2018-08-12             30
# 876  Zellmer, Jamie     2018-08-19             18
# 877  Zellmer, Jamie     2018-08-26             30
# 878  Zellmer, Jamie     2018-09-02             29
# 879  Zellmer, Jamie     2018-09-09             26
# 880  Zellmer, Jamie     2018-09-16             21
# 881  Zellmer, Jamie     2018-09-23             18
# 882  Zellmer, Jamie     2018-09-30             22
# 883  Zellmer, Jamie     2018-10-07             35
# 884  Zellmer, Jamie     2018-10-14             25
# 885  Zellmer, Jamie     2018-10-21             51
# 886  Zellmer, Jamie     2018-10-28             40
# 887  Zellmer, Jamie     2018-11-04             27
# 888  Zellmer, Jamie     2018-11-11             18
# 889  Zellmer, Jamie     2018-11-18             49
# 890  Zellmer, Jamie     2018-11-25             40
#
# [891 rows x 3 columns]

# %%
top_tech_list = list(top_technician_agg.assigned_to.unique())
top_tech_list
# Out:
# ['Bender, Brendt',
#  'Blount, Dustin',
#  'Cook, Stephanie',
#  'Dakin, Timothy',
#  'Dressler, Derek',
#  'Hilliard, Felix',
#  'Jackson, Tucker',
#  'Kester, Kenny',
#  'McDowell, Joe',
#  'Muthuraman, Vairakumar',
#  'Pappas, Gillian',
#  'Patel, Jighnesh',
#  'Poe, William',
#  'Pronschinske, Cole',
#  'Rasmussen, Ranee',
#  'Tapia Velazco, Manuel',
#  'Velazquez, Nilda',
#  'Walley, Miah',
#  'Weber, James',
#  'Zellmer, Jamie']

# %%
#Exponential Smoothening

result = pd.DataFrame()
score = pd.DataFrame()

for technician in top_tech_list:
    track = top_technician_agg[top_technician_agg.assigned_to == technician]
    track = track[['sys_created_on', 'ticket_counts']]
    
    track_score = dict()
    
    track = track.set_index(['sys_created_on'])
    track.index = pd.to_datetime(track.index)
    
    train = track[:-5]
    test = track[-5:]
    
    model = ExponentialSmoothing(train['ticket_counts'], trend='add').fit()
    pred = pd.DataFrame(model.forecast(5))
    pred = pred.reset_index()
    pred.columns = ['sys_created_on', 'pred_ticket_counts']
    
    track_score['assigned_to'] = technician
    track_score['mae'] = mean_absolute_error(test['ticket_counts'], pred['pred_ticket_counts'])
    track_score['mse'] = mean_squared_error(test['ticket_counts'], pred['pred_ticket_counts'])
    track_score['model'] = 'Exponential Smoothening'
    
    track = track.reset_index()
    track = pd.merge(track, pred, on = 'sys_created_on', how = 'left')
    track['assigned_to'] = technician
    result = result.append(track)
    score = score.append(pd.DataFrame([track_score]))
result.to_csv('Exp_smoothening_result.csv', index = False)
# Out:
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency W-SUN will be used.
#   % freq, ValueWarning)

# %%
score
# Out:
#               assigned_to        mae                    model         mse
# 0          Bender, Brendt   4.200000  Exponential Smoothening   19.000000
# 0          Blount, Dustin   6.984617  Exponential Smoothening   78.559679
# 0         Cook, Stephanie   3.536179  Exponential Smoothening   19.687016
# 0          Dakin, Timothy   3.824176  Exponential Smoothening   21.646560
# 0         Dressler, Derek  13.239598  Exponential Smoothening  302.295755
# 0         Hilliard, Felix  19.491917  Exponential Smoothening  554.611184
# 0         Jackson, Tucker  27.800001  Exponential Smoothening  791.000039
# 0           Kester, Kenny  11.129438  Exponential Smoothening  167.144184
# 0           McDowell, Joe   5.957397  Exponential Smoothening   45.083524
# 0  Muthuraman, Vairakumar   7.867319  Exponential Smoothening  114.237551
# 0         Pappas, Gillian   5.786106  Exponential Smoothening   50.556590
# 0         Patel, Jighnesh  14.315131  Exponential Smoothening  286.030615
# 0            Poe, William  15.278384  Exponential Smoothening  327.147783
# 0      Pronschinske, Cole  15.563220  Exponential Smoothening  471.520679
# 0        Rasmussen, Ranee  13.480660  Exponential Smoothening  235.298123
# 0   Tapia Velazco, Manuel  11.613297  Exponential Smoothening  224.257152
# 0        Velazquez, Nilda  13.301267  Exponential Smoothening  265.048636
# 0            Walley, Miah  10.935316  Exponential Smoothening  182.270954
# 0            Weber, James  15.240614  Exponential Smoothening  312.854267
# 0          Zellmer, Jamie  15.128895  Exponential Smoothening  343.268629

# %%
#Arima Forecasting

result = pd.DataFrame()

for technician in top_tech_list:
    track = top_technician_agg[top_technician_agg.assigned_to == technician]
    track = track[['sys_created_on', 'ticket_counts']]
    
    track_score = dict()
    
    track = track.set_index(['sys_created_on'])
    track.index = pd.to_datetime(track.index)
    
    train = track[:-5]
    test = track[-5:]
    
    model = auto_arima(train['ticket_counts'], seasonal=False)
    model.fit(train['ticket_counts'])
    pred = pd.DataFrame(model.predict(5))
    pred = pred.reset_index()
    pred.columns = ['sys_created_on', 'pred_ticket_counts']
    pred['sys_created_on'] = test.index
    
    track_score['assigned_to'] = technician
    track_score['mae'] = mean_absolute_error(test['ticket_counts'], pred['pred_ticket_counts'])
    track_score['mse'] = mean_squared_error(test['ticket_counts'], pred['pred_ticket_counts'])
    track_score['model'] = 'Arima'
    
    track = track.reset_index()
    track = pd.merge(track, pred, on = 'sys_created_on', how = 'left')
    track['assigned_to'] = technician
    result = result.append(track)
    score = score.append(pd.DataFrame([track_score]))
result.to_csv('Arima_result.csv', index = False)
# Out:
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\base\model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ABHISHEK\AppData\Roaming\Python\Python37\site-packages\statsmodels\tsa\statespace\sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
result
# Out:
#    sys_created_on  ticket_counts  pred_ticket_counts     assigned_to
# 0      2018-01-14             27                 NaN  Bender, Brendt
# 1      2018-01-21             63                 NaN  Bender, Brendt
# 2      2018-01-28             61                 NaN  Bender, Brendt
# 3      2018-02-04             75                 NaN  Bender, Brendt
# 4      2018-02-11             66                 NaN  Bender, Brendt
# 5      2018-02-18             59                 NaN  Bender, Brendt
# 6      2018-02-25             77                 NaN  Bender, Brendt
# 7      2018-03-04             72                 NaN  Bender, Brendt
# 8      2018-03-11             72                 NaN  Bender, Brendt
# 9      2018-03-18             81                 NaN  Bender, Brendt
# 10     2018-03-25             58                 NaN  Bender, Brendt
# 11     2018-04-01             52                 NaN  Bender, Brendt
# 12     2018-04-08             55                 NaN  Bender, Brendt
# 13     2018-04-15             49                 NaN  Bender, Brendt
# 14     2018-04-22             47                 NaN  Bender, Brendt
# 15     2018-04-29             57                 NaN  Bender, Brendt
# 16     2018-05-06             66                 NaN  Bender, Brendt
# 17     2018-05-13             61                 NaN  Bender, Brendt
# 18     2018-05-20             70                 NaN  Bender, Brendt
# 19     2018-05-27             88                 NaN  Bender, Brendt
# 20     2018-06-03            108                 NaN  Bender, Brendt
# 21     2018-06-10            114                 NaN  Bender, Brendt
# 22     2018-06-17            140                 NaN  Bender, Brendt
# 23     2018-06-24            122                 NaN  Bender, Brendt
# 24     2018-07-01             66                 NaN  Bender, Brendt
# 25     2018-07-08             51                 NaN  Bender, Brendt
# 26     2018-07-15             53                 NaN  Bender, Brendt
# 27     2018-07-22             55                 NaN  Bender, Brendt
# 28     2018-07-29             53                 NaN  Bender, Brendt
# 29     2018-08-05             55                 NaN  Bender, Brendt
# ..            ...            ...                 ...             ...
# 15     2018-05-06             40                 NaN  Zellmer, Jamie
# 16     2018-05-13             38                 NaN  Zellmer, Jamie
# 17     2018-05-20            109                 NaN  Zellmer, Jamie
# 18     2018-05-27            108                 NaN  Zellmer, Jamie
# 19     2018-06-03             88                 NaN  Zellmer, Jamie
# 20     2018-06-10             86                 NaN  Zellmer, Jamie
# 21     2018-06-17             90                 NaN  Zellmer, Jamie
# 22     2018-06-24             56                 NaN  Zellmer, Jamie
# 23     2018-07-01             72                 NaN  Zellmer, Jamie
# 24     2018-07-08             30                 NaN  Zellmer, Jamie
# 25     2018-07-15             20                 NaN  Zellmer, Jamie
# 26     2018-07-22             16                 NaN  Zellmer, Jamie
# 27     2018-07-29             16                 NaN  Zellmer, Jamie
# 28     2018-08-05             11                 NaN  Zellmer, Jamie
# 29     2018-08-12             30                 NaN  Zellmer, Jamie
# 30     2018-08-19             18                 NaN  Zellmer, Jamie
# 31     2018-08-26             30                 NaN  Zellmer, Jamie
# 32     2018-09-02             29                 NaN  Zellmer, Jamie
# 33     2018-09-09             26                 NaN  Zellmer, Jamie
# 34     2018-09-16             21                 NaN  Zellmer, Jamie
# 35     2018-09-23             18                 NaN  Zellmer, Jamie
# 36     2018-09-30             22                 NaN  Zellmer, Jamie
# 37     2018-10-07             35                 NaN  Zellmer, Jamie
# 38     2018-10-14             25                 NaN  Zellmer, Jamie
# 39     2018-10-21             51                 NaN  Zellmer, Jamie
# 40     2018-10-28             40           47.253536  Zellmer, Jamie
# 41     2018-11-04             27           44.605510  Zellmer, Jamie
# 42     2018-11-11             18           42.733868  Zellmer, Jamie
# 43     2018-11-18             49           41.410979  Zellmer, Jamie
# 44     2018-11-25             40           40.475952  Zellmer, Jamie
#
# [891 rows x 4 columns]

# %%
#Moving windown average
X = top_technician_agg[top_technician_agg.assigned_to == 'Bender, Brendt'].ticket_counts
window = 5
history = [X[i] for i in range(len(X)- 15,len(X)-5)]
test = [X[i] for i in range(len(X) - 5, len(X))]
predictions = list()
# walk forward over time steps in test
for t in range(len(test)):
    length = len(history)
    yhat = mean([history[i] for i in range(length-window,length)])
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
# Out:
# predicted=4.600000, expected=6.000000
# predicted=4.600000, expected=6.000000
# predicted=5.400000, expected=3.000000
# predicted=4.800000, expected=6.000000
# predicted=4.400000, expected=5.000000

# %%
#Window Moving Forecasting

result = pd.DataFrame()

for technician in top_tech_list:
    track = top_technician_agg[top_technician_agg.assigned_to == technician]
    
    track = track[['sys_created_on', 'ticket_counts']]
    
    track_score = dict()
    
    track = track.set_index(['sys_created_on'])
    track.index = pd.to_datetime(track.index)
    
    train = track[:-5]
    test_meta = track[-5:]
    
    X = track.ticket_counts
    window = 5
    history = [X[i] for i in range(len(X)- 15,len(X)-5)]
    test = [X[i] for i in range(len(X) - 5, len(X))]
    predictions = list()
    
    # walk forward over time steps in test
    for t in range(len(test)):
        length = len(history)
        yhat = mean([history[i] for i in range(length-window,length)])
        obs = test[t]
        predictions.append(yhat)
        history.append(obs)
        #print('predicted=%f, expected=%f' % (yhat, obs))
    #error = mean_squared_error(test, predictions)
    
    pred = pd.DataFrame()
    pred['sys_created_on'] = test_meta.index
    pred['pred_ticket_counts'] = predictions
    
    track_score['assigned_to'] = technician
    track_score['mae'] = mean_absolute_error(test, predictions)
    track_score['mse'] = mean_squared_error(test, predictions)
    track_score['model'] = 'Window moving Average'
    
    track = track.reset_index()
    track = pd.merge(track, pred, on = 'sys_created_on', how = 'left')
    track['assigned_to'] = technician
    result = result.append(track)
    score = score.append(pd.DataFrame([track_score]))
result.to_csv('Moving_Average_result.csv', index = False)

# %%
score.sort_values('assigned_to').to_csv('Model_score_technician.csv', index = False)

# %%
score.sort_values('assigned_to')
# Out:
#               assigned_to        mae                    model          mse
# 0          Bender, Brendt   4.200000  Exponential Smoothening    19.000000
# 0          Bender, Brendt   4.200000                    Arima    19.000000
# 0          Bender, Brendt   1.400000    Window moving Average     2.296000
# 0          Blount, Dustin   6.984617  Exponential Smoothening    78.559679
# 0          Blount, Dustin   6.984615                    Arima    78.559632
# 0          Blount, Dustin   4.280000    Window moving Average    48.760000
# 0         Cook, Stephanie   3.536179  Exponential Smoothening    19.687016
# 0         Cook, Stephanie  15.046722                    Arima   271.819540
# 0         Cook, Stephanie   2.840000    Window moving Average    15.400000
# 0          Dakin, Timothy   3.824176  Exponential Smoothening    21.646560
# 0          Dakin, Timothy   7.468048                    Arima    65.207962
# 0          Dakin, Timothy   2.680000    Window moving Average    10.392000
# 0         Dressler, Derek  13.239598  Exponential Smoothening   302.295755
# 0         Dressler, Derek  15.664374                    Arima   363.497566
# 0         Dressler, Derek  14.320000    Window moving Average   237.376000
# 0         Hilliard, Felix  27.972774                    Arima  1029.196715
# 0         Hilliard, Felix  21.960000    Window moving Average   789.176000
# 0         Hilliard, Felix  19.491917  Exponential Smoothening   554.611184
# 0         Jackson, Tucker   8.840000    Window moving Average   110.088000
# 0         Jackson, Tucker  27.800001  Exponential Smoothening   791.000039
# 0         Jackson, Tucker  51.418067                    Arima  2649.035376
# 0           Kester, Kenny   6.600000    Window moving Average    60.376000
# 0           Kester, Kenny  11.129438  Exponential Smoothening   167.144184
# 0           Kester, Kenny   5.346274                    Arima    46.277412
# 0           McDowell, Joe   5.636958                    Arima    42.186229
# 0           McDowell, Joe   6.840000    Window moving Average    59.576000
# 0           McDowell, Joe   5.957397  Exponential Smoothening    45.083524
# 0  Muthuraman, Vairakumar   8.720000    Window moving Average   116.016000
# 0  Muthuraman, Vairakumar   7.869604                    Arima   108.781357
# 0  Muthuraman, Vairakumar   7.867319  Exponential Smoothening   114.237551
# 0         Pappas, Gillian   8.414634                    Arima    88.406068
# 0         Pappas, Gillian   5.000000    Window moving Average    32.600000
# 0         Pappas, Gillian   5.786106  Exponential Smoothening    50.556590
# 0         Patel, Jighnesh  10.884907                    Arima   272.266255
# 0         Patel, Jighnesh  16.920000    Window moving Average   390.872000
# 0         Patel, Jighnesh  14.315131  Exponential Smoothening   286.030615
# 0            Poe, William  13.147818                    Arima   182.694726
# 0            Poe, William  15.278384  Exponential Smoothening   327.147783
# 0            Poe, William  13.360000    Window moving Average   279.824000
# 0      Pronschinske, Cole  12.600000    Window moving Average   341.672000
# 0      Pronschinske, Cole  15.473834                    Arima   463.919485
# 0      Pronschinske, Cole  15.563220  Exponential Smoothening   471.520679
# 0        Rasmussen, Ranee  11.160000    Window moving Average   156.440000
# 0        Rasmussen, Ranee  13.480660  Exponential Smoothening   235.298123
# 0        Rasmussen, Ranee  17.545819                    Arima   372.551633
# 0   Tapia Velazco, Manuel  12.800000    Window moving Average   193.872000
# 0   Tapia Velazco, Manuel   6.522299                    Arima    53.193858
# 0   Tapia Velazco, Manuel  11.613297  Exponential Smoothening   224.257152
# 0        Velazquez, Nilda  13.301267  Exponential Smoothening   265.048636
# 0        Velazquez, Nilda  14.800000    Window moving Average   291.024000
# 0        Velazquez, Nilda  11.272965                    Arima   160.191231
# 0            Walley, Miah   9.240000    Window moving Average   112.984000
# 0            Walley, Miah   9.679847                    Arima   144.050918
# 0            Walley, Miah  10.935316  Exponential Smoothening   182.270954
# 0            Weber, James  13.720000    Window moving Average   297.448000
# 0            Weber, James  15.240614  Exponential Smoothening   312.854267
# 0            Weber, James  18.185366                    Arima   401.527424
# 0          Zellmer, Jamie  11.531577                    Arima   206.430348
# 0          Zellmer, Jamie  15.128895  Exponential Smoothening   343.268629
# 0          Zellmer, Jamie  10.960000    Window moving Average   150.960000

# %%
train
# Out:
#                 ticket_counts
# sys_created_on
# 2018-01-14                 27
# 2018-01-21                 63
# 2018-01-28                 61
# 2018-02-04                 75
# 2018-02-11                 66
# 2018-02-18                 59
# 2018-02-25                 77
# 2018-03-04                 72
# 2018-03-11                 72
# 2018-03-18                 81
# 2018-03-25                 58
# 2018-04-01                 52
# 2018-04-08                 55
# 2018-04-15                 49
# 2018-04-22                 47
# 2018-04-29                 57
# 2018-05-06                 66
# 2018-05-13                 61
# 2018-05-20                 70
# 2018-05-27                 88
# 2018-06-03                108
# 2018-06-10                114
# 2018-06-17                140
# 2018-06-24                122
# 2018-07-01                 66
# 2018-07-08                 51
# 2018-07-15                 53
# 2018-07-22                 55
# 2018-07-29                 53
# 2018-08-05                 55
# 2018-08-12                 29
# 2018-08-19                 31
# 2018-08-26                  7
# 2018-09-02                  7
# 2018-09-09                  6
# 2018-09-16                  8
# 2018-09-23                  6
# 2018-09-30                  2
# 2018-10-07                  6
# 2018-10-14                  8
# 2018-10-21                  1
